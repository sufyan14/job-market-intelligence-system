# %% [markdown]
# ## **Text Processing**

# %%
import pandas as pd

combined_canonical = pd.read_csv("/content/combined_canonical_v1.csv")
# Out:
# /tmp/ipython-input-2722424305.py:3: DtypeWarning: Columns (7,8) have mixed types. Specify dtype option on import or set low_memory=False.
#   combined_canonical = pd.read_csv("/content/combined_canonical_v1.csv")

# %%
combined_canonical.info()
combined_canonical.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 129334 entries, 0 to 129333
# Data columns (total 10 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   job_id            129334 non-null  int64
#  1   job_title         129334 non-null  object
#  2   company           129334 non-null  object
#  3   location          129334 non-null  object
#  4   experience_level  99932 non-null   object
#  5   job_description   129334 non-null  object
#  6   salary_final      11772 non-null   float64
#  7   industry          5491 non-null    object
#  8   sub_industry      5491 non-null    object
#  9   source            129334 non-null  object
# dtypes: float64(1), int64(1), object(8)
# memory usage: 9.9+ MB
# job_id                   0
# job_title                0
# company                  0
# location                 0
# experience_level     29402
# job_description          0
# salary_final        117562
# industry            123843
# sub_industry        123843
# source                   0
# dtype: int64

# %% [markdown]
# ### Text Cleaning

# %% [markdown]
# Transformed job_description into clean_description by:
#
# - Converting text to lowercase
#
# - Removing HTML tags
#
# - Removing punctuation, numbers, and special characters
#
# - Normalizing whitespace
#
# - Safely handling missing values (NaN → "")

# %%
import re

def clean_text(text):
    if pd.isna(text):
        return ""
    text = text.lower()
    text = re.sub(r"<.*?>", " ", text)
    text = re.sub(r"[^a-zA-Z\s]", " ", text)
    text = re.sub(r"\s+", " ", text).strip()
    return text

combined_canonical["clean_description"] = combined_canonical["job_description"].apply(clean_text)

# %%
combined_canonical["clean_description"].head()
combined_canonical["clean_description"].str.len().describe()
# Out:
# count    129334.000000
# mean       3660.648484
# std        2145.967257
# min           2.000000
# 25%        2095.000000
# 50%        3326.000000
# 75%        4836.750000
# max       31522.000000
# Name: clean_description, dtype: float64

# %% [markdown]
# ### Stopword Removal

# %% [markdown]
# Removed high-frequency, low-information words using NLTK which include:
#
# - the, and, is, for, with, to, of
#
# **Why this is necessary**
#
# These words:
#
# - Appear in almost every document
#
# - Carry no skill, role, or domain information
#
# - Inflate feature space later
#
# Removing them:
#
# - Improves signal-to-noise ratio
#
# - Makes skills like python, sql, aws stand out
#
# - Improves clustering and modeling quality later

# %%
import nltk
nltk.download("stopwords")
from nltk.corpus import stopwords

stop_words = set(stopwords.words("english"))

def remove_stopwords(text):
    return " ".join(w for w in text.split() if w not in stop_words)

combined_canonical["clean_description"] = combined_canonical["clean_description"].apply(remove_stopwords)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %% [markdown]
# ### Verification
#
# This includes:
#
# - Before and after clean description check
# - Length Reduction Check
# - Stopword Effect Check
# - Null Safety Check

# %%
combined_canonical[
    ["job_description", "clean_description"]
].sample(5, random_state=42)
# Out:
#                                          job_description  \
# 35000  Description\n\nCompany: Oak Street Health\n\nT...
# 35370  LOCATION: Watertown / New York (US-NY), United...
# 328    The Terra Forza Golf team is growing! Territor...
# 63701  The ideal candidate is a skilled professional ...
# 21765  Position Summary...\n\nAs a Bakery Department ...
#
#                                        clean_description
# 35000  description company oak street health title me...
# 35370  location watertown new york us ny united state...
# 328    terra forza golf team growing territory determ...
# 63701  ideal candidate skilled professional passionat...
# 21765  position summary bakery department lead drive ...

# %%
"the" in combined_canonical["clean_description"].iloc[0].split()
# Out:
# False

# %%
combined_canonical["job_description"].str.len().describe()
combined_canonical["clean_description"].str.len().describe()
# Out:
# count    129334.000000
# mean       2980.924792
# std        1731.072435
# min           2.000000
# 25%        1721.000000
# 50%        2739.000000
# 75%        3935.000000
# max       25010.000000
# Name: clean_description, dtype: float64

# %%
combined_canonical["clean_description"].isnull().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ### Inspect Most Common Tokens

# %%
from collections import Counter

all_words = " ".join(combined_canonical["clean_description"]).split()
common_words = Counter(all_words).most_common(30)
common_words
# Out:
# [('experience', 398816),
#  ('work', 371327),
#  ('team', 260841),
#  ('skills', 205574),
#  ('job', 192258),
#  ('including', 189339),
#  ('ability', 180643),
#  ('business', 179234),
#  ('management', 176906),
#  ('required', 175554),
#  ('time', 172546),
#  ('company', 164643),
#  ('position', 160449),
#  ('customer', 151481),
#  ('support', 150492),
#  ('benefits', 141826),
#  ('service', 135044),
#  ('years', 133483),
#  ('care', 133077),
#  ('information', 132343),
#  ('health', 125345),
#  ('sales', 124034),
#  ('requirements', 121252),
#  ('must', 118153),
#  ('services', 117519),
#  ('may', 117206),
#  ('opportunity', 117012),
#  ('data', 116101),
#  ('development', 115662),
#  ('status', 114136)]

# %% [markdown]
# ### Noise Word Set

# %%
noise_words = {
    "experience", "years", "year", "ability", "skills", "knowledge",
    "role", "responsibilities", "responsible", "work", "working",
    "team", "teams", "looking", "candidate", "position", "job",
    "required", "preferred", "strong", "excellent", "good", "including",
    "time", "company", "benefits", "requirements", "must", "may", "opportunity"
}

# %% [markdown]
# ### Noise Removal

# %%
def remove_noise_words(text):
    return " ".join(
        word for word in text.split()
        if word not in noise_words
    )

combined_canonical["clean_description"] = (
    combined_canonical["clean_description"]
    .apply(remove_noise_words)
)

# %% [markdown]
# ### After Removal Check

# %%
from collections import Counter

Counter(
    " ".join(combined_canonical["clean_description"]).split()
).most_common(20)
# Out:
# [('business', 179234),
#  ('management', 176906),
#  ('customer', 151481),
#  ('support', 150492),
#  ('service', 135044),
#  ('care', 133077),
#  ('information', 132343),
#  ('health', 125345),
#  ('sales', 124034),
#  ('services', 117519),
#  ('data', 116101),
#  ('development', 115662),
#  ('status', 114136),
#  ('new', 112181),
#  ('environment', 110247),
#  ('employment', 109014),
#  ('provide', 107242),
#  ('related', 103396),
#  ('customers', 101993),
#  ('medical', 98617)]

# %% [markdown]
# ### Update the Dataset

# %%
combined_canonical.to_csv(
    "/content/combined_canonical_v2.csv",
    index=False
)

# %%
combined_canonical.columns
# Out:
# Index(['job_id', 'job_title', 'company', 'location', 'experience_level',
#        'job_description', 'salary_final', 'industry', 'sub_industry', 'source',
#        'clean_description'],
#       dtype='object')

# %% [markdown]
# ### Import Required Tools

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %% [markdown]
# ## Configure TF-IDF

# %%
tfidf = TfidfVectorizer(
    max_features=5000,
    ngram_range=(1, 2),
    min_df=5,
    max_df=0.8
)

# %% [markdown]
# ## Fit & transform

# %%
X_tfidf = tfidf.fit_transform(
    combined_canonical["clean_description"]
)

# %% [markdown]
# ## Sanity checks

# %%
X_tfidf.shape
# Out:
# (129334, 5000)

# %% [markdown]
# ### Vocabulary inspection

# %%
tfidf.get_feature_names_out()[:20]
# Out:
# array(['aa', 'abilities', 'abilities include', 'able', 'able communicate',
#        'able lift', 'able perform', 'able read', 'abreast', 'absence',
#        'abuse', 'academic', 'academy', 'accelerate', 'accept',
#        'acceptable', 'acceptance', 'accepted', 'accepting', 'access'],
#       dtype=object)

# %% [markdown]
# ### Non-zero density check

# %%
X_tfidf.nnz / (X_tfidf.shape[0] * X_tfidf.shape[1])
# Out:
# 0.0456680316080845

# %% [markdown]
# ## Persist artifacts

# %%
import joblib

joblib.dump(tfidf, "tfidf_vectorizer_v1.pkl")
joblib.dump(X_tfidf, "X_tfidf_v1.pkl")
# Out:
# ['X_tfidf_v1.pkl']

# %%
SKILL_VOCAB = {
    "python", "java", "sql", "excel", "power bi", "tableau",
    "machine learning", "deep learning", "nlp",
    "tensorflow", "pytorch",
    "aws", "azure", "gcp",
    "docker", "kubernetes",
    "react", "node", "fastapi", "django",
    "git", "linux"
}

# %%
def extract_skills(text, skill_vocab):
    found = set()
    text = text.lower()
    for skill in skill_vocab:
        if skill in text:
            found.add(skill)
    return list(found)

combined_canonical["extracted_skills"] = combined_canonical[
    "clean_description"
].apply(lambda x: extract_skills(x, SKILL_VOCAB))

# %%
combined_canonical[["job_title", "extracted_skills"]].tail(50)
# Out:
#                                                 job_title extracted_skills
# 129284                           Experienced Travel Agent          [excel]
# 129285                                       Travel Agent               []
# 129286    Reservation Specialist / Customer Service Agent               []
# 129287            Reservation Specialist Vacation Rentals               []
# 129288                             Reservation Specialist               []
# 129289                   Reservation Specialist/Part Time          [excel]
# 129290                             Reservation Specialist               []
# 129291                             Reservation Specialist               []
# 129292               Travel Advisor - Corporate & Leisure               []
# 129293                          Luxury Travel Sales Agent               []
# 129294  Adventure Assistant Administrative Assistant/T...               []
# 129295                    Reservation Specialist/Pet Care          [excel]
# 129296                                  Travel Consultant               []
# 129297                             Reservation Specialist               []
# 129298                      Experienced Travel Consultant               []
# 129299                             Reservation Specialist               []
# 129300  LOTTERY-Accounts Payable Travel Specialist (Ac...          [excel]
# 129301                             Reservation Specialist               []
# 129302              Corporate / Leisure Travel Consultant          [excel]
# 129303                             Reservation Specialist               []
# 129304                                  Travel Consultant               []
# 129305                  Reservation Specialist/Dispatcher            [aws]
# 129306   Mechanical Engineering Expert - Remote w/ Travel          [excel]
# 129307   Reservation Specialist / Front Desk Receptionist     [aws, excel]
# 129308                               Travel Support Agent     [git, excel]
# 129309                             Reservation Specialist               []
# 129310            Sales Associate/ Reservation Specialist               []
# 129311                   Leisure Travel Sales Coordinator          [excel]
# 129312                          Travel Specialist, Senior     [git, excel]
# 129313                             Reservation Specialist               []
# 129314     Reservation Specialist, Assistant to the Owner          [excel]
# 129315  Customer Care Specialist - Reservation (Phoeni...               []
# 129316  Adventure Assistant Administrative Assistant/T...               []
# 129317                                       Travel Agent               []
# 129318           Reservation Specialist | Zephyr Cove, NV          [excel]
# 129319  Pet Care Customer Service Rep - Reservation Sp...               []
# 129320                                      Travel Agents          [excel]
# 129321                  Reservation Specialist (Pet Care)     [aws, excel]
# 129322                                       Travel Agent          [excel]
# 129323                         Travel Agent - Experienced               []
# 129324              Reservation and Accounting Specialist            [aws]
# 129325                        Host/Reservation Specialist               []
# 129326                             Reservation Specialist               []
# 129327                             Reservation Specialist               []
# 129328                             Reservation Specialist               []
# 129329                                       TRAVEL AGENT            [aws]
# 129330  LOTTERY-Accounts Payable Travel Specialist (Ac...          [excel]
# 129331              Reservation Specialist/Beach Services               []
# 129332                                 Travel Coordinator     [git, excel]
# 129333                             Reservation Specialist               []
