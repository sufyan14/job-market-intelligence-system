# %% [markdown]
# ## **Text Processing**

# %%
import pandas as pd

combined_canonical = pd.read_csv("/content/combined_canonical_v1.csv")
# Out:
# /tmp/ipython-input-2722424305.py:3: DtypeWarning: Columns (7,8) have mixed types. Specify dtype option on import or set low_memory=False.
#   combined_canonical = pd.read_csv("/content/combined_canonical_v1.csv")

# %%
combined_canonical.info()
combined_canonical.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 129334 entries, 0 to 129333
# Data columns (total 10 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   job_id            129334 non-null  int64
#  1   job_title         129334 non-null  object
#  2   company           129334 non-null  object
#  3   location          129334 non-null  object
#  4   experience_level  99932 non-null   object
#  5   job_description   129334 non-null  object
#  6   salary_final      11772 non-null   float64
#  7   industry          5491 non-null    object
#  8   sub_industry      5491 non-null    object
#  9   source            129334 non-null  object
# dtypes: float64(1), int64(1), object(8)
# memory usage: 9.9+ MB
# job_id                   0
# job_title                0
# company                  0
# location                 0
# experience_level     29402
# job_description          0
# salary_final        117562
# industry            123843
# sub_industry        123843
# source                   0
# dtype: int64

# %% [markdown]
# ### Text Cleaning

# %% [markdown]
# Transformed job_description into clean_description by:
#
# - Converting text to lowercase
#
# - Removing HTML tags
#
# - Removing punctuation, numbers, and special characters
#
# - Normalizing whitespace
#
# - Safely handling missing values (NaN → "")

# %%
import re

def clean_text(text):
    if pd.isna(text):
        return ""
    text = text.lower()
    text = re.sub(r"<.*?>", " ", text)
    text = re.sub(r"[^a-zA-Z\s]", " ", text)
    text = re.sub(r"\s+", " ", text).strip()
    return text

combined_canonical["clean_description"] = combined_canonical["job_description"].apply(clean_text)

# %%
combined_canonical["clean_description"].head()
combined_canonical["clean_description"].str.len().describe()
# Out:
# count    129334.000000
# mean       3660.648484
# std        2145.967257
# min           2.000000
# 25%        2095.000000
# 50%        3326.000000
# 75%        4836.750000
# max       31522.000000
# Name: clean_description, dtype: float64

# %% [markdown]
# ### Stopword Removal

# %% [markdown]
# Removed high-frequency, low-information words using NLTK which include:
#
# - the, and, is, for, with, to, of
#
# **Why this is necessary**
#
# These words:
#
# - Appear in almost every document
#
# - Carry no skill, role, or domain information
#
# - Inflate feature space later
#
# Removing them:
#
# - Improves signal-to-noise ratio
#
# - Makes skills like python, sql, aws stand out
#
# - Improves clustering and modeling quality later

# %%
import nltk
nltk.download("stopwords")
from nltk.corpus import stopwords

stop_words = set(stopwords.words("english"))

def remove_stopwords(text):
    return " ".join(w for w in text.split() if w not in stop_words)

combined_canonical["clean_description"] = combined_canonical["clean_description"].apply(remove_stopwords)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %% [markdown]
# ### Verification
#
# This includes:
#
# - Before and after clean description check
# - Length Reduction Check
# - Stopword Effect Check
# - Null Safety Check

# %%
combined_canonical[
    ["job_description", "clean_description"]
].sample(5, random_state=42)
# Out:
#                                          job_description  \
# 35000  Description\n\nCompany: Oak Street Health\n\nT...
# 35370  LOCATION: Watertown / New York (US-NY), United...
# 328    The Terra Forza Golf team is growing! Territor...
# 63701  The ideal candidate is a skilled professional ...
# 21765  Position Summary...\n\nAs a Bakery Department ...
#
#                                        clean_description
# 35000  description company oak street health title me...
# 35370  location watertown new york us ny united state...
# 328    terra forza golf team growing territory determ...
# 63701  ideal candidate skilled professional passionat...
# 21765  position summary bakery department lead drive ...

# %%
"the" in combined_canonical["clean_description"].iloc[0].split()
# Out:
# False

# %%
combined_canonical["job_description"].str.len().describe()
combined_canonical["clean_description"].str.len().describe()
# Out:
# count    129334.000000
# mean       2980.924792
# std        1731.072435
# min           2.000000
# 25%        1721.000000
# 50%        2739.000000
# 75%        3935.000000
# max       25010.000000
# Name: clean_description, dtype: float64

# %%
combined_canonical["clean_description"].isnull().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ### Inspect Most Common Tokens

# %%
from collections import Counter

all_words = " ".join(combined_canonical["clean_description"]).split()
common_words = Counter(all_words).most_common(30)
common_words
# Out:
# [('experience', 398816),
#  ('work', 371327),
#  ('team', 260841),
#  ('skills', 205574),
#  ('job', 192258),
#  ('including', 189339),
#  ('ability', 180643),
#  ('business', 179234),
#  ('management', 176906),
#  ('required', 175554),
#  ('time', 172546),
#  ('company', 164643),
#  ('position', 160449),
#  ('customer', 151481),
#  ('support', 150492),
#  ('benefits', 141826),
#  ('service', 135044),
#  ('years', 133483),
#  ('care', 133077),
#  ('information', 132343),
#  ('health', 125345),
#  ('sales', 124034),
#  ('requirements', 121252),
#  ('must', 118153),
#  ('services', 117519),
#  ('may', 117206),
#  ('opportunity', 117012),
#  ('data', 116101),
#  ('development', 115662),
#  ('status', 114136)]

# %% [markdown]
# ### Noise Word Set

# %%
noise_words = {
    "experience", "years", "year", "ability", "skills", "knowledge",
    "role", "responsibilities", "responsible", "work", "working",
    "team", "teams", "looking", "candidate", "position", "job",
    "required", "preferred", "strong", "excellent", "good", "including",
    "time", "company", "benefits", "requirements", "must", "may", "opportunity"
}

# %% [markdown]
# ### Noise Removal

# %%
def remove_noise_words(text):
    return " ".join(
        word for word in text.split()
        if word not in noise_words
    )

combined_canonical["clean_description"] = (
    combined_canonical["clean_description"]
    .apply(remove_noise_words)
)

# %% [markdown]
# ### After Removal Check

# %%
from collections import Counter

Counter(
    " ".join(combined_canonical["clean_description"]).split()
).most_common(20)
# Out:
# [('business', 179234),
#  ('management', 176906),
#  ('customer', 151481),
#  ('support', 150492),
#  ('service', 135044),
#  ('care', 133077),
#  ('information', 132343),
#  ('health', 125345),
#  ('sales', 124034),
#  ('services', 117519),
#  ('data', 116101),
#  ('development', 115662),
#  ('status', 114136),
#  ('new', 112181),
#  ('environment', 110247),
#  ('employment', 109014),
#  ('provide', 107242),
#  ('related', 103396),
#  ('customers', 101993),
#  ('medical', 98617)]

# %% [markdown]
# ### Update the Dataset

# %%
combined_canonical.to_csv(
    "/content/combined_canonical_v2.csv",
    index=False
)

# %%
combined_canonical.columns
# Out:
# Index(['job_id', 'job_title', 'company', 'location', 'experience_level',
#        'job_description', 'salary_final', 'industry', 'sub_industry', 'source',
#        'clean_description'],
#       dtype='object')

# %% [markdown]
# ### Import Required Tools

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %% [markdown]
# ## Configure TF-IDF

# %%
tfidf = TfidfVectorizer(
    max_features=5000,
    ngram_range=(1, 2),
    min_df=5,
    max_df=0.8
)

# %% [markdown]
# ## Fit & transform

# %%
X_tfidf = tfidf.fit_transform(
    combined_canonical["clean_description"]
)

# %% [markdown]
# ## Sanity checks

# %%
X_tfidf.shape
# Out:
# (129334, 5000)

# %% [markdown]
# ### Vocabulary inspection

# %%
tfidf.get_feature_names_out()[:20]
# Out:
# array(['aa', 'abilities', 'abilities include', 'able', 'able communicate',
#        'able lift', 'able perform', 'able read', 'abreast', 'absence',
#        'abuse', 'academic', 'academy', 'accelerate', 'accept',
#        'acceptable', 'acceptance', 'accepted', 'accepting', 'access'],
#       dtype=object)

# %% [markdown]
# ### Non-zero density check

# %%
X_tfidf.nnz / (X_tfidf.shape[0] * X_tfidf.shape[1])
# Out:
# 0.0456680316080845

# %% [markdown]
# ## Persist artifacts

# %%
import joblib

joblib.dump(tfidf, "tfidf_vectorizer_v1.pkl")
joblib.dump(X_tfidf, "X_tfidf_v1.pkl")
# Out:
# ['X_tfidf_v1.pkl']

# %% [markdown]
# ## Build a skill vocabulary

# %%
SKILL_VOCAB = {
    "python", "java", "sql", "excel", "power bi", "tableau",
    "machine learning", "deep learning", "nlp",
    "tensorflow", "pytorch",
    "aws", "azure", "gcp",
    "docker", "kubernetes",
    "react", "node", "fastapi", "django",
    "git", "linux"
}

# %% [markdown]
# ### Extract skills from each job

# %%
def extract_skills(text, skill_vocab):
    found = set()
    text = text.lower()
    for skill in skill_vocab:
        if skill in text:
            found.add(skill)
    return list(found)

combined_canonical["extracted_skills"] = combined_canonical[
    "clean_description"
].apply(lambda x: extract_skills(x, SKILL_VOCAB))

# %% [markdown]
# ### Verify and Do Sanity Check

# %%
combined_canonical[["job_title", "extracted_skills"]].tail(50)
# Out:
#                                                 job_title extracted_skills
# 129284                           Experienced Travel Agent          [excel]
# 129285                                       Travel Agent               []
# 129286    Reservation Specialist / Customer Service Agent               []
# 129287            Reservation Specialist Vacation Rentals               []
# 129288                             Reservation Specialist               []
# 129289                   Reservation Specialist/Part Time          [excel]
# 129290                             Reservation Specialist               []
# 129291                             Reservation Specialist               []
# 129292               Travel Advisor - Corporate & Leisure               []
# 129293                          Luxury Travel Sales Agent               []
# 129294  Adventure Assistant Administrative Assistant/T...               []
# 129295                    Reservation Specialist/Pet Care          [excel]
# 129296                                  Travel Consultant               []
# 129297                             Reservation Specialist               []
# 129298                      Experienced Travel Consultant               []
# 129299                             Reservation Specialist               []
# 129300  LOTTERY-Accounts Payable Travel Specialist (Ac...          [excel]
# 129301                             Reservation Specialist               []
# 129302              Corporate / Leisure Travel Consultant          [excel]
# 129303                             Reservation Specialist               []
# 129304                                  Travel Consultant               []
# 129305                  Reservation Specialist/Dispatcher            [aws]
# 129306   Mechanical Engineering Expert - Remote w/ Travel          [excel]
# 129307   Reservation Specialist / Front Desk Receptionist     [excel, aws]
# 129308                               Travel Support Agent     [excel, git]
# 129309                             Reservation Specialist               []
# 129310            Sales Associate/ Reservation Specialist               []
# 129311                   Leisure Travel Sales Coordinator          [excel]
# 129312                          Travel Specialist, Senior     [excel, git]
# 129313                             Reservation Specialist               []
# 129314     Reservation Specialist, Assistant to the Owner          [excel]
# 129315  Customer Care Specialist - Reservation (Phoeni...               []
# 129316  Adventure Assistant Administrative Assistant/T...               []
# 129317                                       Travel Agent               []
# 129318           Reservation Specialist | Zephyr Cove, NV          [excel]
# 129319  Pet Care Customer Service Rep - Reservation Sp...               []
# 129320                                      Travel Agents          [excel]
# 129321                  Reservation Specialist (Pet Care)     [excel, aws]
# 129322                                       Travel Agent          [excel]
# 129323                         Travel Agent - Experienced               []
# 129324              Reservation and Accounting Specialist            [aws]
# 129325                        Host/Reservation Specialist               []
# 129326                             Reservation Specialist               []
# 129327                             Reservation Specialist               []
# 129328                             Reservation Specialist               []
# 129329                                       TRAVEL AGENT            [aws]
# 129330  LOTTERY-Accounts Payable Travel Specialist (Ac...          [excel]
# 129331              Reservation Specialist/Beach Services               []
# 129332                                 Travel Coordinator     [excel, git]
# 129333                             Reservation Specialist               []

# %%
combined_canonical[
    combined_canonical["extracted_skills"].str.len() > 0
][["job_title", "extracted_skills"]].head(20)
# Out:
#                                             job_title extracted_skills
# 1                   Mental Health Therapist/Counselor          [excel]
# 3   Senior Elder Law / Trusts and Estates Associat...          [excel]
# 8                               Respiratory Therapist   [react, excel]
# 10                  Inside Customer Service Associate          [excel]
# 11                                  Project Architect     [excel, git]
# 12      Appalachian Highlands Women's Business Center          [excel]
# 14                   Senior Product Marketing Manager            [git]
# 16                         Administrative Coordinator            [aws]
# 18                     Content Writer, Communications          [excel]
# 19                                         Controller          [excel]
# 24                           Personal Injury Attorney          [excel]
# 26                                  Software Engineer      [java, sql]
# 27                                   Loan Coordinator          [excel]
# 28                                    General Laborer          [excel]
# 30                           Administrative Assistant          [excel]
# 31                  Service / Construction Technician          [excel]
# 34                                   Registered Nurse          [excel]
# 35                     Marketing & Office Coordinator     [excel, git]
# 36                        Software Support Specialist           [java]
# 37  Coordinator for Multicultural Student Organiza...            [aws]

# %% [markdown]
# ### Creating Skill Dictionaries

# %%
technical_skills = {
    "python", "java", "c++", "javascript", "sql", "excel",
    "aws", "azure", "gcp",
    "docker", "kubernetes",
    "git", "linux",
    "tensorflow", "pytorch",
    "power bi", "tableau"
}

# %%
domain_skills = {
    "data analysis", "data science", "machine learning",
    "web development", "backend", "frontend",
    "cloud computing", "devops",
    "cybersecurity", "networking"
}

# %%
business_tools = {
    "excel", "word", "powerpoint",
    "crm", "sap", "salesforce",
    "jira", "confluence"
}

# %% [markdown]
# ### Re-Run Extraction

# %%
def extract_skills(text, skill_vocab):
    text = text.lower()
    return sorted([
        skill for skill in skill_vocab
        if skill in text
    ])

# %% [markdown]
# #### Added Missing Column

# %%
combined_canonical["job_text"] = (
    combined_canonical["job_title"].fillna("") + " " +
    combined_canonical["clean_description"].fillna("")
)

# %% [markdown]
# ### Coverage Check

# %%
combined_canonical["skills_v2"] = combined_canonical["job_text"].apply(
    lambda x: extract_skills(x, SKILL_VOCAB)
)

coverage = (
    combined_canonical["skills_v2"].str.len() > 0
).mean()

coverage
# Out:
# np.float64(0.534631264787295)

# %% [markdown]
# ### Sanity Check

# %%
combined_canonical[
    combined_canonical["skills_v2"].str.len() > 0
][["job_title", "skills_v2"]].sample(20)
# Out:
#                                                 job_title  \
# 88869                                  Back End Developer
# 124459                               Humanities Librarian
# 93134                           Technical Support Analyst
# 68548             Digital & Visitor Media Sales Executive
# 15754                                Sales Representative
# 91423                       Sales Associate-HANES MALL II
# 6995                  Registered Nurse RN Home Health PRN
# 75881                 QC Security Installation Technician
# 73712                                    Senior Associate
# 100468                                    Plant Associate
# 86349                                   Account Executive
# 109927                                EVS Aide - Evenings
# 104797                                       Merchandiser
# 47315                         Order Management Specialist
# 120925                                 Supply Coordinator
# 29163   Anti-Money Laundering (AML) Sr. Investigator I...
# 101486  Stockroom Lead Associate Part Time- TOMMY HILF...
# 118898   Registered Nurse (RN)— Intensive Care Unit (ICU)
# 92553                     Risk Control Consultant-Hortica
# 37570   Phlebotomist, Laboratory - Support, $10000 Bon...
#
#                            skills_v2
# 88869   [docker, excel, java, react]
# 124459                         [git]
# 93134                          [aws]
# 68548                          [git]
# 15754                          [aws]
# 91423                   [aws, excel]
# 6995                           [aws]
# 75881                   [aws, excel]
# 73712                        [excel]
# 100468                         [aws]
# 86349                        [excel]
# 109927                         [aws]
# 104797                         [aws]
# 47315                   [aws, excel]
# 120925                  [aws, excel]
# 29163                          [aws]
# 101486                  [aws, excel]
# 118898                       [excel]
# 92553                        [excel]
# 37570                        [excel]

# %% [markdown]
# ## Creating Normalized Skill Column

# %%
# Skill normalization map (v1)
skill_map = {
    "amazon web services": "aws",
    "aws cloud": "aws",
    "reactjs": "react",
    "nodejs": "node",
    "javascript": "javascript",
    "js": "javascript",
    "python3": "python",
    "k8s": "kubernetes",
    "postgres": "postgresql",
    "postgre": "postgresql",
}

def normalize_skills(skill_list):
    if not isinstance(skill_list, list):
        return []
    normalized = []
    for s in skill_list:
        s = s.lower().strip()
        normalized.append(skill_map.get(s, s))
    return list(set(normalized))  # remove duplicates

combined_canonical["skills_norm"] = combined_canonical["skills_v2"].apply(normalize_skills)

# %% [markdown]
# ### Verify Normalization

# %%
combined_canonical[["skills_v2", "skills_norm"]].sample(10)
# Out:
#           skills_v2  skills_norm
# 22036            []           []
# 61561         [aws]        [aws]
# 107914           []           []
# 59175       [excel]      [excel]
# 65139            []           []
# 87144            []           []
# 23034            []           []
# 23466            []           []
# 127370        [aws]        [aws]
# 965     [java, sql]  [java, sql]

# %% [markdown]
# ### Skill frequency table

# %%
from collections import Counter

all_skills = combined_canonical["skills_norm"].explode()
skill_counts = Counter(all_skills.dropna())

skill_freq_df = (
    pd.DataFrame(skill_counts.items(), columns=["skill", "count"])
      .sort_values("count", ascending=False)
)

skill_freq_df.head(20)
# Out:
#                skill  count
# 0              excel  40025
# 3                aws  23233
# 2                git  14815
# 5                sql   6322
# 9             python   5274
# 4               java   4345
# 1              react   3298
# 10             azure   3087
# 12             linux   1957
# 14  machine learning   1897
# 6            tableau   1388
# 16        kubernetes   1316
# 7           power bi   1221
# 15            docker   1188
# 11               gcp   1158
# 8               node    935
# 17     deep learning    313
# 18           pytorch    281
# 20        tensorflow    260
# 13               nlp    238

# %% [markdown]
# ### Sanity checks

# %%
skill_freq_df.tail(20)
# Out:
#                skill  count
# 2                git  14815
# 5                sql   6322
# 9             python   5274
# 4               java   4345
# 1              react   3298
# 10             azure   3087
# 12             linux   1957
# 14  machine learning   1897
# 6            tableau   1388
# 16        kubernetes   1316
# 7           power bi   1221
# 15            docker   1188
# 11               gcp   1158
# 8               node    935
# 17     deep learning    313
# 18           pytorch    281
# 20        tensorflow    260
# 13               nlp    238
# 21            django    122
# 19           fastapi     35

# %%
skill_freq_df.describe()
# Out:
#               count
# count     22.000000
# mean    5123.090909
# std     9530.486126
# min       35.000000
# 25%      468.500000
# 50%     1352.000000
# 75%     4083.250000
# max    40025.000000

# %%
skill_freq_df[skill_freq_df["count"] > 10000]
# Out:
#    skill  count
# 0  excel  40025
# 3    aws  23233
# 2    git  14815

# %% [markdown]
# ### Save artifacts

# %%
skill_freq_df.to_csv("skill_frequency_v1.csv", index=False)
combined_canonical.to_csv("combined_with_skills_norm_v1.csv", index=False)

# %%
skill_freq_df["percentage"] = (
    skill_freq_df["count"] / skill_freq_df["count"].sum()
).round(4)

# %% [markdown]
# ## Creating Views For Skills

# %% [markdown]
# ### Top Skills by Frequency (Absolute Demand)

# %%
top_n = 20

top_skills = skill_freq_df.sort_values("count", ascending=False).head(top_n)

top_skills
# Out:
#                skill  count  percentage
# 0              excel  40025      0.3551
# 3                aws  23233      0.2061
# 2                git  14815      0.1314
# 5                sql   6322      0.0561
# 9             python   5274      0.0468
# 4               java   4345      0.0386
# 1              react   3298      0.0293
# 10             azure   3087      0.0274
# 12             linux   1957      0.0174
# 14  machine learning   1897      0.0168
# 6            tableau   1388      0.0123
# 16        kubernetes   1316      0.0117
# 7           power bi   1221      0.0108
# 15            docker   1188      0.0105
# 11               gcp   1158      0.0103
# 8               node    935      0.0083
# 17     deep learning    313      0.0028
# 18           pytorch    281      0.0025
# 20        tensorflow    260      0.0023
# 13               nlp    238      0.0021

# %%
import matplotlib.pyplot as plt

plt.figure()
plt.barh(top_skills["skill"], top_skills["count"])
plt.xlabel("Job Postings Count")
plt.ylabel("Skill")
plt.title("Top 20 Skills by Frequency")
plt.gca().invert_yaxis()
plt.show()

# %% [markdown]
# ### Skill Demand Percentage (Relative Market Share)

# %%
top_skills_pct = skill_freq_df.sort_values("percentage", ascending=False).head(top_n)

top_skills_pct
# Out:
#                skill  count  percentage
# 0              excel  40025      0.3551
# 3                aws  23233      0.2061
# 2                git  14815      0.1314
# 5                sql   6322      0.0561
# 9             python   5274      0.0468
# 4               java   4345      0.0386
# 1              react   3298      0.0293
# 10             azure   3087      0.0274
# 12             linux   1957      0.0174
# 14  machine learning   1897      0.0168
# 6            tableau   1388      0.0123
# 16        kubernetes   1316      0.0117
# 7           power bi   1221      0.0108
# 15            docker   1188      0.0105
# 11               gcp   1158      0.0103
# 8               node    935      0.0083
# 17     deep learning    313      0.0028
# 18           pytorch    281      0.0025
# 20        tensorflow    260      0.0023
# 13               nlp    238      0.0021

# %%
plt.figure()
plt.barh(top_skills_pct["skill"], top_skills_pct["percentage"])
plt.xlabel("Percentage of Job Postings")
plt.ylabel("Skill")
plt.title("Top 20 Skills by Market Share")
plt.gca().invert_yaxis()
plt.show()

# %%
skill_freq_sorted = skill_freq_df.sort_values("count", ascending=False)
skill_freq_sorted["cumulative_percentage"] = skill_freq_sorted["percentage"].cumsum()

skill_freq_sorted.head(30)
# Out:
#                skill  count  percentage  cumulative_percentage
# 0              excel  40025      0.3551                 0.3551
# 3                aws  23233      0.2061                 0.5612
# 2                git  14815      0.1314                 0.6926
# 5                sql   6322      0.0561                 0.7487
# 9             python   5274      0.0468                 0.7955
# 4               java   4345      0.0386                 0.8341
# 1              react   3298      0.0293                 0.8634
# 10             azure   3087      0.0274                 0.8908
# 12             linux   1957      0.0174                 0.9082
# 14  machine learning   1897      0.0168                 0.9250
# 6            tableau   1388      0.0123                 0.9373
# 16        kubernetes   1316      0.0117                 0.9490
# 7           power bi   1221      0.0108                 0.9598
# 15            docker   1188      0.0105                 0.9703
# 11               gcp   1158      0.0103                 0.9806
# 8               node    935      0.0083                 0.9889
# 17     deep learning    313      0.0028                 0.9917
# 18           pytorch    281      0.0025                 0.9942
# 20        tensorflow    260      0.0023                 0.9965
# 13               nlp    238      0.0021                 0.9986
# 21            django    122      0.0011                 0.9997
# 19           fastapi     35      0.0003                 1.0000

# %% [markdown]
# ### Long-Tail Distribution (Skill Inequality)

# %%
plt.figure()
plt.plot(skill_freq_sorted["cumulative_percentage"].values)
plt.xlabel("Skills Ranked by Frequency")
plt.ylabel("Cumulative Percentage")
plt.title("Cumulative Skill Demand Distribution")
plt.show()
